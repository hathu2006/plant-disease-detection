# %% [markdown]
# # Demo — Chẩn đoán bệnh cây trồng qua ảnh lá
#
# Chạy lần lượt 2 cell bên dưới (Runtime > Run all). Cell thứ 2 in ra một link `https://xxxxx.gradio.live` — bấm vào để mở demo (link sống ~72 giờ).
#
# Không cần GPU, không cần đăng nhập gì. Mã nguồn & case study: https://github.com/hathu2006/plant-disease-detection

# %%
# !git clone https://github.com/hathu2006/plant-disease-detection.git
# %cd plant-disease-detection
# !pip install -q -r requirements.txt

# %%
import os
os.environ['MODEL_PATH'] = 'models/mobilenetv2_pv_plantdoc.keras'
import app
app.demo.launch(share=True)
